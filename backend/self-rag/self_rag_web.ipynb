# %%
from typing import List, TypedDict, Literal
from pydantic import BaseModel, Field

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate

from langchain_community.tools.tavily_search import TavilySearchResults


from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv

load_dotenv()
# Out:
# C:\Users\zaine\AppData\Local\Temp\ipykernel_11564\4089055371.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# True

# %%
docs = (
    PyPDFLoader("./documents/DSwithBappy_Company_Policies.pdf").load()
    + PyPDFLoader("./documents/DSwithBappy_Company_Profile.pdf").load()
    + PyPDFLoader("./documents/DSwithBappy_Product_and_Pricing.pdf").load()
)

# %%
chunks = RecursiveCharacterTextSplitter(
    chunk_size=600, chunk_overlap=150
).split_documents(docs)

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
vector_store = FAISS.from_documents(chunks, embeddings)
retriever = vector_store.as_retriever(search_kwargs={"k": 4})

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
class State(TypedDict):
    question: str
    need_retrieval: bool

    docs: List[Document]
    relevant_docs: List[Document]

    context: str
    answer: str

    # web query (no loop flags)
    web_query: str

# %%
class RetrieveDecision(BaseModel):
    should_retrieve: bool = Field(
        ...,
        description="True if external documents are needed to answer reliably, else False."
    )

decide_retrieval_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You decide whether retrieval is needed.\n"
            "Return JSON that matches this schema:\n"
            "{{'should_retrieve': boolean}}\n\n"
            "Guidelines:\n"
            "- should_retrieve=True if answering requires specific facts, citations, or info likely not in the model.\n"
            "- should_retrieve=False for general explanations, definitions, or reasoning that doesn't need sources.\n"
            "- If unsure, choose True."
        ),
        ("human", "Question: {question}"),
    ]
)


# IMPORTANT: no `.content` for structured output
should_retrieve_llm = llm.with_structured_output(RetrieveDecision)

def decide_retrieval(state: "State"):
    decision: RetrieveDecision = should_retrieve_llm.invoke(
        decide_retrieval_prompt.format_messages(question=state["question"])
    )
    return {"need_retrieval": decision.should_retrieve}

# %%
direct_generation_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Answer the question using only your general knowledge.\n"
            "Do NOT assume access to external documents.\n"
            "If you are unsure or the answer requires specific sources, say:\n"
            "'I don't know based on my general knowledge.'"
        ),
        ("human", "{question}"),
    ]
)


def generate_direct(state: State):
    out = llm.invoke(
        direct_generation_prompt.format_messages(
            question=state["question"]
        )
    )
    return {
        "answer": out.content
    }

# %%
def retrieve(state: State):
    return {"docs": retriever.invoke(state["question"])}

# %%
class RelevanceDecision(BaseModel):
    is_relevant: bool = Field(
        ...,
        description="True if the document helps answer the question, else False."
    )

is_relevant_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are judging document relevance.\n"
            "Return JSON that matches this schema:\n"
            "{{'is_relevant': boolean}}\n\n"
            "A document is relevant if it contains information useful for answering the question."
        ),
        (
            "human",
            "Question:\n{question}\n\nDocument:\n{document}"
        ),
    ]
)

relevance_llm = llm.with_structured_output(RelevanceDecision)

def is_relevant(state: State):
    
    relevant_docs: List[Document] = []

    for doc in state["docs"]:
        decision: RelevanceDecision = relevance_llm.invoke(
            is_relevant_prompt.format_messages(
                question=state["question"],
                document=doc.page_content
            )
        )

        if decision.is_relevant:
            relevant_docs.append(doc)

    return {"relevant_docs": relevant_docs}

# %%
# New
rag_generation_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a business RAG assistant.\n"
            "Answer the user's question using ONLY the provided context.\n"
            "If the context does not contain enough information, say:\n"
            "'No relevant document found.'\n"
            "Do not use outside knowledge.\n"
        ),
        (
            "human",
            "Question:\n{question}\n\n"
            "Context:\n{context}\n"
        ),
    ]
)

def generate_from_context(state: State):
    # Stuff relevant docs into one block
    context = "\n\n---\n\n".join(
        [d.page_content for d in state.get("relevant_docs", [])]
    ).strip()

    if not context:
        return {"answer": "No relevant document found.", "context": ""}

    out = llm.invoke(
        rag_generation_prompt.format_messages(
            question=state["question"],
            context=context
        )
    )
    return {"answer": out.content, "context": context}

# %%
class WebQuery(BaseModel):
    query: str

rewrite_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Rewrite the user question into a web search query composed of keywords.\n"
            "Rules:\n"
            "- Keep it short (6–14 words).\n"
            "- If the question implies recency, add (last 30 days).\n"
            "- Do NOT answer the question.\n"
            "- Return JSON with a single key: query",
        ),
        ("human", "Question: {question}"),
    ]
)

rewrite_chain = rewrite_prompt | llm.with_structured_output(WebQuery)

def rewrite_query_node(state: State):
    out = rewrite_chain.invoke({"question": state["question"]})
    return {"web_query": out.query}

tavily = TavilySearchResults(max_results=5)

def web_search_node(state: State):
    q = state.get("web_query") or state["question"]
    results = tavily.invoke({"query": q})

    docs = []
    for r in results or []:
        title = r.get("title", "")
        url = r.get("url", "")
        content = r.get("content", "") or r.get("snippet", "")
        text = f"TITLE: {title}\nURL: {url}\nCONTENT:\n{content}"
        docs.append(
            Document(
                page_content=text,
                metadata={"source": "web", "url": url, "title": title},
            )
        )

    return {"docs": docs}
# Out:
# C:\Users\zaine\AppData\Local\Temp\ipykernel_11564\948566410.py:25: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tavily = TavilySearchResults(max_results=5)

# %%
# New
def no_relevant_docs(state: State):
    return {"answer": "No relevant document found.", "context": ""}

# %%
def route_after_decide(state: State) -> Literal["generate_direct", "retrieve"]:
    if state["need_retrieval"]:
        return "retrieve"
    return "generate_direct"

# %%
def route_after_relevance(state: State) -> Literal["generate_from_context", "rewrite_query"]:
    if state.get("relevant_docs") and len(state["relevant_docs"]) > 0:
        return "generate_from_context"
    return "rewrite_query"

# %%
g = StateGraph(State)

g.add_node("decide_retrieval", decide_retrieval)
g.add_node("generate_direct", generate_direct)
g.add_node("retrieve", retrieve)

g.add_node("is_relevant", is_relevant)
g.add_node("generate_from_context", generate_from_context)

# ✅ new nodes (replace no_relevant_docs)
g.add_node("rewrite_query", rewrite_query_node)
g.add_node("web_search", web_search_node)

# --------------------
# Edges
# --------------------
g.add_edge(START, "decide_retrieval")

g.add_conditional_edges(
    "decide_retrieval",
    route_after_decide,
    {
        "generate_direct": "generate_direct",
        "retrieve": "retrieve",
    },
)

g.add_edge("generate_direct", END)

# vector retrieval → relevance
g.add_edge("retrieve", "is_relevant")

# relevance router: if relevant → generate, else → rewrite_query
g.add_conditional_edges(
    "is_relevant",
    route_after_relevance,
    {
        "generate_from_context": "generate_from_context",
        "rewrite_query": "rewrite_query",
    },
)

# web fallback path
g.add_edge("rewrite_query", "web_search")
g.add_edge("web_search", "is_relevant")  # 🔁 circle back

# final
g.add_edge("generate_from_context", END)

app = g.compile()
app

# %%
result = app.invoke(
    {
        "question": "Who won the Aus vs Zim World T20 match 2026 and who was the top scorer",
        "docs": [],
        "relevant_docs": [],
        "context": "",
        "answer": "",
    }
)

print(result["answer"])
# Out:
# Zimbabwe won the Aus vs Zim World T20 match in 2026 by 23 runs. The top scorer for Zimbabwe was Brian Bennett, who scored 64 runs.

# %%
for doc in result['relevant_docs']:
    print(doc.page_content)
    print("*"*100)
# Out:
# TITLE: AUS vs ZIM Head To Head Records- T20 World Cup 2026, Match 19 | CREX
# URL: https://crex.com/cricket-news/aus-vs-zim-head-to-head-records-t20-world-cup-2026-match-19-698db1c857f15b1c44fb1381
# CONTENT:
# Title: AUS vs ZIM Head To Head Records- T20 World Cup 2026, Match 19 | CREX
# # AUS vs ZIM Head To Head Records- T20 World Cup 2026, Match 19. ![Australia vs Zimbabwe [Source: AFP]](https://onecricketnews.akamaized.net/parth-editor/oc-dashboard/news-images-prod/1770890270664_AUS vs ZIM.jpg)Australia vs Zimbabwe [Source: AFP]. ![Australia vs Zimbabwe [Source: AFP]](https://onecricketnews.akamaized.net/parth-editor/oc-dashboard/news-images-prod/1770890270664_AUS vs ZIM.jpg). Australia and Zimbabwe are set to face each other in the 19th match of the T20 World Cup 2026. ## Australia vs Zimbabwe Head to Head Records in T20Is. ## Australia vs Zimbabwe Highest Team Total In T20Is. The highest team total in T20 matches between Australia and Zimbabwe is 229 runs, scored by Australia. ## Australia vs Zimbabwe Lowest Team Total in T20Is. The lowest team total in AUS vs ZIM T20Is is 129 all out, scored by Zimbabwe. ## AUS vs ZIM Highest Individual Score in T20Is. Aaron Finch has the highest individual score in T20I matches between Australia and Zimbabwe. ## Australia vs Zimbabwe Best Bowling Figures in T20Is. Andrew Tye has the best bowling figures in T20 matches between Australia and Zimbabwe. ## Most Runs In AUS vs ZIM T20Is. Aaron Finch (Australia) holds the record for scoring the most runs in AUS vs ZIM T20Is. Notably, Finch tops the list with 175 runs in two innings, making him the standout batter in this matchup. ## Most Wickets in AUS vs ZIM T20Is. When it comes to bowling, Andrew Tye has taken the most wickets in AUS vs ZIM T20Is. He took 6 wickets in 2 innings and maintained an impressive economy rate of 5 runs per over. ## Top Run Scorer of the last AUS vs ZIM T20I match. In the recent T20I match between Australia and Zimbabwe, Solomon Mire was the top run scorer. ## Top Wicket Taker of the last AUS vs ZIM T20I match. In the most recent T20I match between Australia and Zimbabwe in 2018, Blessing Muzarabani was the top wicket-taker. ## AUS vs ZIM T20I Form (Last 5 Match). Overall, in the AUS vs ZIM T20I head-to-head record, Australia are ahead, having won 2 out of the 3 matches played between the two teams. ## IND vs NAM Head to Head Records- ICC T20 World Cup 2026, Match 18.
# ****************************************************************************************************
# TITLE: AUS vs ZIM Result: ZIM Won by 23 runs, Match Summary | Cricket Winner
# URL: https://www.cricketwinner.com/live-cricket-score/aus-vs-zim-group-b-19th-match-icc-mens-t20-world-cup-2026-02-13
# CONTENT:
# ✓ Finished13 Feb 2026 · R.Premadasa Stadium
#
# # Australia vs Zimbabwe Match Info, Live Score & Highlights19th Match, ICC Men's T20 World Cup 2026 · 11:00 am IST
#
# AUS
#
# AUS · Home
#
# 146/10 (19.3)
#
# VS
#
# FULL TIME
#
# ZIM
#
# Zimbabwe
#
# ZIM · Away
#
# 169/2 (20)
#
# 🏆 Zimbabwe won by 23 runs
#
# Blessing Muzarabani
#
# ★ Player of the Match
#
# Blessing MuzarabaniZIM
#
# 4 wkts
#
# InfoScorecardOvers40Playing XIStatsResultsView PredictionDiscussion0
#
# ## AUS vs ZIM Match Info
#
# 19th Match · T20I
#
# Match19th Match, WCT20 2026
#
# SeriesICC Men's T20 World Cup 2026
#
# Date13 Feb 2026
#
# Time11:00 am IST · 05:30 GMT
#
# VenueR.Premadasa Stadium, Colombo
#
# TossAUSwon the toss & chose to bat
#
# UmpiresChris Gaffaney, Raveendra Wimalasiri
#
# 3rd UmpireRichard Illingworth
#
# Match RefereeRichie Richardson
#
# ## Venue Stats
#
# Last 20 at this ground [...] CSE
#
# Toss Index457.2▲ +2.89%Match Index1,108.6▲ +4.27%TIX-CPL2653.2▲ +2.89%TIX-SLTO26115.2▲ +6.66%Caribbean Premier League 2026 · CSXM3631 ABF vs JK▬ +0.00%M3630 ZIM vs AUS▲ +4.27%M3629 JPN vs HK▬ +0.00%M3628 ENG vs SL▲ +4.27%M3627 ZIM-W vs SA-W▲ +4.27%M3626 JPN vs HK▲ +4.27%M3625 JK vs GAW▼ −4.30%M3624 ZIM vs AUS▲ +1.77%M3623 GAW vs ABF▼ −4.48%M3622 ENG vs SL▲ +4.27%Toss Index457.2▲ +2.89%Match Index1,108.6▲ +4.27%TIX-CPL2653.2▲ +2.89%TIX-SLTO26115.2▲ +6.66%Caribbean Premier League 2026 · CSXM3631 ABF vs JK▬ +0.00%M3630 ZIM vs AUS▲ +4.27%M3629 JPN vs HK▬ +0.00%M3628 ENG vs SL▲ +4.27%M3627 ZIM-W vs SA-W▲ +4.27%M3626 JPN vs HK▲ +4.27%M3625 JK vs GAW▼ −4.30%M3624 ZIM vs AUS▲ +1.77%M3623 GAW vs ABF▼ −4.48%M3622 ENG vs SL▲ +4.27%
#
# ✓ Finished13 Feb 2026 · R.Premadasa Stadium
# ****************************************************************************************************
# TITLE: Zimbabwe beat Australia  by 23 runs - Australia vs Zimbabwe, ICC Men's T20 World Cup 2026, 19th Match, Group B Match Summary, Report | ESPN.com
# URL: https://www.espn.com/cricket/series/8604/game/1512737/australia-vs-zimbabwe-19th-match-group-b-icc-mens-t20-world-cup-2025-26
# CONTENT:
# #### Points
#
# Zimbabwe 2, Australia 0
#
# # Scorecard Summary
#
# #### ZIMBABWE 169/2(20 OVERS)
#
#    Tadiwanashe Marumani35 (21)
#    Brian Bennett64 (56)
#
#    Marcus Stoinis1/17 (2.5)
#    Cameron Green1/6 (1.1)
#
# #### AUSTRALIA 146(19.3 OVERS)
#
#    Glenn Maxwell31 (32)
#    Matt Renshaw65 (44)
#
#    Brad Evans3/23 (3.3)
#    Blessing Muzarabani4/17 (4)
#
# Full Scorecard
#
# Scorer: Ranjith P | Commentator: Abhimanyu Bose [...] Image 232: ZimbabweZimbabwe Zimbabwe ZIM 169/2
#    Image 233: AustraliaAustralia Australia AUS 146 (19.3/20 ov)
#
# Zimbabwe won by 23 runs
#
# Player of the Match
#
# Image 234: Blessing Muzarabani
#
# Blessing Muzarabani Zimbabwe
#
#    Summary Summary
#    Scorecard Scorecard
#    Report Report
#    Commentary Commentary
#    Videos Videos
#    Coverage Coverage
#    Statistics Statistics
#    Table Table
#
# Image 235
#
# 2/13/2026 Alex Malcolm
#
# # Muzarabani, Evans and Bennett slay Australia
#
# Australia were never really in the contest - they picked up two wickets in Zimbabwe's entire innings and lost four in their batting powerplay - and fell well short in the end
#
# # Match Centre
#
# # Statistics
#
# ### Best performances - Batsmen
#
#  5x4 - 1x6
#
# Control %84%
#
#    Productive Shot
#    straight drive
#    11 runs
#    1x4 - 1x6 [...] ## Australia 2nd innings Partnerships
#
# | Wkt | Runs | Players |  |
#  ---  --- |
# | 1st | 13 | TM Head | JP Inglis |
# | 2nd | 11 | TM Head | C Green |
# | 3rd | 1 | TM Head | TH David |
# | 4th | 4 | GJ Maxwell | TM Head |
# | 5th | 77 | GJ Maxwell | MT Renshaw |
# | 6th | 11 | MP Stoinis | MT Renshaw |
# | 7th | 14 | BJ Dwarshuis | MT Renshaw |
# | 8th | 8 | MT Renshaw | NT Ellis |
# | 9th | 2 | A Zampa | NT Ellis |
# | 10th | 5 | MP Kuhnemann | NT Ellis |
#
#    1/3
#
# # ICC Men's T20 World Cup
#
# | Super Eights, Group 1 |
#
# | Team | M | W | L | PT | NRR |
# | SA | 3 | 3 | 0 | 6 | 2.259 |
# | IND | 3 | 2 | 1 | 4 | 0.106 |
# | WI | 3 | 1 | 2 | 2 | 0.993 |
# | ZIM | 3 | 0 | 3 | 0 | -3.415 |
# ****************************************************************************************************
# TITLE: AUS vs ZIM Dream11 Prediction Match 19, ICC T20 World Cup 2026
# URL: https://www.sportsdunia.com/fantasy-cricket/aus-vs-zim-dream11-prediction-match-19-t20-world-cup-2026
# CONTENT:
# | Australia Playing XI | Zimbabwe Playing XI |
#  --- |
# | Travis Head (c) | Tadiwanashe Marumani |
# | Josh Inglis | Brian Bennett |
# | Cameron Green | Dion Myers |
# | Matt Renshaw | Brendon Taylor |
# | Cooper Connolly | Sikandar Raza (c) |
# | Marcus Stoinis | Ryan Burl |
# | Glenn Maxwell | Tashinga Musekiwa |
# | Xavier Bartlett | Brad Evans |
# | Nathan Ellis | Wellington Masakadza |
# | Adam Zampa | Richard Ngarava |
# | Matthew Kuhnemann | Blessing Muzarabani |
#
# ## AUS vs ZIM Top Run Scorers and Leading Wicket Takers
#
# |  |  |
#  --- |
# | Highest Run Scorer | Marcus Stoinis and Brian Bennett |
# | Highest Wicket Takers | Nathan Ellis and Blessing Muzarabani |
#
# Advertisement
#
# ## AUS vs ZIM Captain and Vice Captain Choices [...] ## Australia vs Zimbabwe Match Details
#
# |  |  |
#  --- |
# | Series | ICC Men's T20 World Cup 2026 |
# | Match | Australia vs Zimbabwe, 19th Match |
# | Toss | To be updated |
# | Venue | R. Premadasa Stadium |
# | City | Colombo |
# | Match Start Time | 11:00 AM IST, 13th February 2026 |
# | Scorecard | Australia vs Zimbabwe Scorecard |
# | Live Streaming | JioHotstar |
#
# ## AUS vs ZIM Dream11 Team Today Stats
#
# Zimbabwe Cricket Team (Image Credits: Official X Account of ICC/@ICC)
#
# | Player | Team | Player’s Stats (Last Match) |
#  ---
# | Marcus Stoinis | Australia | 45 Runs |
# | Nathan Ellis | Australia | 4 Wickets |
# | Brian Bennett | Zimbabwe | 48 Runs |
# | Blessing Muzarabani | Zimbabwe | 3 Wickets |
#
# Advertisement
#
# ## AUS vs ZIM Toss Prediction [...] Australia will take on Zimbabwe in Match 19 of the ICC Men’s T20 World Cup 2026 at the R. Premadasa Stadium, Colombo, with both sides eyeing the Super Eight qualification. Australia defeated Ireland by 67 runs in their first encounter of the tournament. Although they are without the likes of some of the best T20 batsmen in the world, like Mitchell Marsh and Tim David, they still form a formidable batting lineup.
# ****************************************************************************************************

# %%
len(result['relevant_docs'])
# Out:
# 4
